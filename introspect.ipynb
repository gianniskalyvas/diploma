# %%
import os
path = "/workspace"
os.chdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1898873330.py in <cell line: 0>()
#       1 import os
#       2 path = "/workspace"
# ----> 3 os.chdir(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace'

# %% [markdown]
# make sure:
#  * vm runs inference in the correct model
#
# ```
# export HUGGING_FACE_HUB_TOKEN="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"
#
# docker run --gpus all --shm-size 1g -p 3000:80   -e HUGGING_FACE_HUB_TOKEN=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   ghcr.io/huggingface/text-generation-inference   --model-id meta-llama/Llama-2-7b-chat-hf
#
# python -m vllm.entrypoints.api_server   --model meta-llama/Llama-3.2-1B-Instruct   --port 3000   --tensor-parallel-size 1 --gpu_memory_utilization 0.5
# ```
#  * --clean-cache

# %% [markdown]
# ###introspect

# %%
import sys
sys.path.append('/usr/local/lib/python3.12/dist-packages')

# %%
# !pip install -U datasets
# Out:
# /content/drive/MyDrive/thesis/code/llm-introspection-main/introspect

# %%
os.chdir(path + "/llm-introspection-main")
# !python3 -m pip install -e .
# Out:
# ...
# Obtaining file:///content/drive/My%20Drive/thesis/code/llm-introspection-main
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 56.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 15.9 MB/s eta 0:00:00
# ...
#   Building editable for introspect (pyproject.toml) ... done
#   Created wheel for introspect: filename=introspect-0.1.0-0.editable-py3-none-any.whl size=3073 sha256=235871fd393b1e699fdaec6155d4c366f552a2bf512d951a1924d8bc7085d141
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v8_iqbtc/wheels/8b/c6/f0/c356696a780e8f3c65ca358f8c3b49e7a094191c580dd71e59
# ...

# %%
import datasets
builder = datasets.load_dataset_builder(path + '/eraserbenchmark-master/esnli_dataset_builder')
os.chdir(path + "/llm-introspection-main/introspect")
builder.download_and_prepare()
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
import os
os.chdir("/workspace/llm-introspection-main")
persistent_dir = "/workspace/introspections/esnli_introspections/Llama-3.2-1B-Instruct"
# !python3 experiments/analysis.py  --persistent-dir {persistent_dir}  --endpoint http://localhost:3000  --task counterfactual  --task-config ''  --model-name llama3  --dataset RTE  --split test  --seed 0 --max-workers 1 --client VLLM
